# %% [markdown]
# # 2020 빅콘테스트 데이터분석 분야 - 퓨처스 리그
#
# ![](https://www.bigcontest.or.kr/images/main/visual_bg.jpg)
#
# 빅콘테스트 홈페이지: https://www.bigcontest.or.kr/

# %% [markdown]
# # 1. 팀 소개
# ![](./img/merona.png)
#
# ## 1.1 팀 이름
# > **건너건너**
#
# ## 1.2 팀원 구성 및 역할
#     - 팀장
#         - 안희재 (숙명여자대학교 4학년, heejae5628@gmail.com)
#     - 팀원
#         - 김민정 (숙명여자대학교 3학년, kmmnjng528@gmail.com)
#         - 김채현 (숙명여자대학교 3학년, 7chaeny25@gmail.com)
#         - 이혜원 (숙명여자대학교 3학년, hyewon903@gmail.com)

# %% [markdown]
# # 2. 대회요강
#
# ## 2.1 문제
# -	KBO 정규시즌 팀별 승률, 타율 및 방어율(평균자책점) 예측
# - 스포츠투아이에서 제공하는 야구데이터(팀 통산 전적자료, 연도별 전적자료, 팀 및 선수 기록 등)를 활용하여 경진대회 종료 이후, 정규시즌 잔여 경기에 대한 각 팀별 승률, 타율 및 방어율(평균자책점) 예측

# %% [markdown]
# ## 2.2 데이터 설명
#
# ### 2.2.1 팀.csv
# > 팀명, 팀코드
#
# - 2020빅콘테스트_스포츠투아이_제공데이터_팀 _2016
# - 2020빅콘테스트_스포츠투아이_제공데이터_팀 _2017
# - 2020빅콘테스트_스포츠투아이_제공데이터_팀 _2018
# - 2020빅콘테스트_스포츠투아이_제공데이터_팀 _2019
# - 2020빅콘테스트_스포츠투아이_제공데이터_팀 _2020
#
# ### 2.2.2 경기.csv
# > 게임키, 일자, 원정팀코드, 홈팀코드, 더블헤더코드, 요일, 구장
#
# - 2020빅콘테스트_스포츠투아이_제공데이터_경기_2016
# - 2020빅콘테스트_스포츠투아이_제공데이터_경기_2017
# - 2020빅콘테스트_스포츠투아이_제공데이터_경기_2018
# - 2020빅콘테스트_스포츠투아이_제공데이터_경기_2019
# - 2020빅콘테스트_스포츠투아이_제공데이터_경기_2020
#
# ### 2.2.3 선수.csv
# > 시즌, 선수코드, 선수명, 팀코드, 포지션, 나이, 연봉
#
# - 2020빅콘테스트_스포츠투아이_제공데이터_선수_2016
# - 2020빅콘테스트_스포츠투아이_제공데이터_선수_2017
# - 2020빅콘테스트_스포츠투아이_제공데이터_선수_2018
# - 2020빅콘테스트_스포츠투아이_제공데이터_선수_2019
# - 2020빅콘테스트_스포츠투아이_제공데이터_선수_2020
#
# ### 2.2.4 팀투수.csv
# > 게임키, 일자, 팀코드, 상대팀코드, 더블헤더코드, 초말, 완투, 결과, 홀드, 이닝*3, 투구수, 타자, 타수, 안타, 2루타, 3루타, 홈런, 도루, 도루실패, 희타, 4구, 고4, 사구, 삼진, 병살타, 폭투, 보크, 실책, 실점, 자책점, 득점권WHIP, 2점차이하WHIP, 345번타자WHIP
#
# - 2020빅콘테스트_스포츠투아이_제공데이터_팀투수_2016
# - 2020빅콘테스트_스포츠투아이_제공데이터_팀투수_2017
# - 2020빅콘테스트_스포츠투아이_제공데이터_팀투수_2018
# - 2020빅콘테스트_스포츠투아이_제공데이터_팀투수_2019
# - 2020빅콘테스트_스포츠투아이_제공데이터_팀투수_2020
#
# ### 2.2.5 팀타자.csv
# > 게임키, 일자, 팀코드, 상대팀코드, 더블헤더코드, 초말, 타자, 타수, 타점, 득점, 안타, 2루타, 3루타, 홈런, 도루, 도루실패, 희타, 희비, 4구, 고4, 사구, 삼진, 병살타, 실책, 잔루, 득점권타율, 득점권타수, 득점권안타
#
# - 2020빅콘테스트_스포츠투아이_제공데이터_팀타자_2016
# - 2020빅콘테스트_스포츠투아이_제공데이터_팀타자_2017
# - 2020빅콘테스트_스포츠투아이_제공데이터_팀타자_2018
# - 2020빅콘테스트_스포츠투아이_제공데이터_팀타자_2019
# - 2020빅콘테스트_스포츠투아이_제공데이터_팀타자_2020
#
# ### 2.2.6 개인투수.csv
# > 게임키, 일자, 팀코드, 상대팀코드, 더블헤더코드, 초말, 선수코드, 선발, 구원, 완투, 종료, 결과, 홀드, 이닝*3, 투구수, 타자, 타수, 안타, 2루타, 3루타, 홈런, 도루, 도루실패, 희타, 4구, 고4, 사구, 삼진, 병살타, 폭투, 보크, 실책, 실점, 자책점, 득점권WHIP, 2점차이하WHIP, 345번타자WHIP
#
# - 2020빅콘테스트_스포츠투아이_제공데이터_개인투수_2016
# - 2020빅콘테스트_스포츠투아이_제공데이터_개인투수_2017
# - 2020빅콘테스트_스포츠투아이_제공데이터_개인투수_2018
# - 2020빅콘테스트_스포츠투아이_제공데이터_개인투수_2019
# - 2020빅콘테스트_스포츠투아이_제공데이터_개인투수_2020
#
# ### 2.2.7 개인타자.csv
# > 게임키, 일자, 팀코드, 상대팀코드, 더블헤더코드, 초말, 선수코드, 선발, 타순,  타자, 타수, 타점, 득점, 안타, 2루타, 3루타, 홈런, 도루, 도루실패, 희타, 희비, 4구, 고4, 사구, 삼진, 병살타, 실책, 잔루, 득점권타율, 득점권타수, 득점권안타
#
# - 2020빅콘테스트_스포츠투아이_제공데이터_개인타자_2016
# - 2020빅콘테스트_스포츠투아이_제공데이터_개인타자_2017
# - 2020빅콘테스트_스포츠투아이_제공데이터_개인타자_2018
# - 2020빅콘테스트_스포츠투아이_제공데이터_개인타자_2019
# - 2020빅콘테스트_스포츠투아이_제공데이터_개인타자_2020
#
# ### 2.2.8 등록선수.csv
# > 일자, 팀코드, 선수코드, 등록말소
#
# - 2020빅콘테스트_스포츠투아이_제공데이터_등록선수_2016
# - 2020빅콘테스트_스포츠투아이_제공데이터_등록선수_2017
# - 2020빅콘테스트_스포츠투아이_제공데이터_등록선수_2018
# - 2020빅콘테스트_스포츠투아이_제공데이터_등록선수_2019
# - 2020빅콘테스트_스포츠투아이_제공데이터_등록선수_2020

# %% [markdown]
# ---
#
# # 3. 라이브러리 및 옵션 (Load Library and Set Option)

# %% [markdown]
# ## 3.1 라이브러리 (Library)

# %%
# 데이터 분석 기본 라이브러리 관련
import os
import sys
import warnings
from tqdm import tqdm_notebook

import numpy as np
import pandas as pd

# EDA 관련
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# 데이터 전처리 관련
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# 머신러닝 모델 관련
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import minmax_scale
from sklearn import datasets
from scipy.stats import probplot
from scipy import stats
from sklearn.metrics import r2_score

# %% [markdown]
# ## 3.2 옵션 (Option)

# %%
warnings.filterwarnings(action='ignore')
pd.set_option('display.max_columns', 100)
mpl.rcParams['font.family'] = 'Malgun Gothic'
mpl.rcParams['axes.unicode_minus'] = False
plt.style.use('ggplot')

# %% [markdown]
# ---
#
# # 4. 탐색적 데이터 분석 (Exploratory Data Analysis, EDA)

# %% [markdown]
# ---
#
# ## 4.1 데이터 불러오기

# %%
BASE_PATH_SEASON_SHEET = 'data/2020빅콘테스트 데이터분석분야-퓨쳐스리그_스포츠투아이_제공데이터(.CSV)_시즌별, 시트별 구분'
BASE_PATH_SEASON = 'data/2020빅콘테스트 데이터분석분야-퓨쳐스리그_스포츠투아이_제공데이터(.xlsx)_시즌별 구분'

# %%
# 파일 불러오기

file_dict = {}
for var,key in zip(['개인타자','개인투수','경기','등록선수','선수','팀타자','팀투수','팀'],
                ['ind_hitter','ind_pitcher','match','reg_player','player','team_hitter','team_pitcher','team']):
    print(f'{var} 데이터 불러오기',end='')
    var_dict = {}
    for year in range(2016, 2021):
        data = pd.read_csv(f'{BASE_PATH_SEASON_SHEET}/2020빅콘테스트_스포츠투아이_제공데이터_{var}_{year}.csv', encoding ='cp949')
        var_dict[year] = data
    file_dict[key] = var_dict
    print('---> 완료')
# Out:
# 개인타자 데이터 불러오기---> 완료
# 개인투수 데이터 불러오기---> 완료
# 경기 데이터 불러오기---> 완료
# 등록선수 데이터 불러오기---> 완료
# 선수 데이터 불러오기---> 완료
# 팀타자 데이터 불러오기---> 완료
# 팀투수 데이터 불러오기---> 완료
# 팀 데이터 불러오기---> 완료

# %%
#파일 합치기
## 2016년부터 2020년 7월 19일의 경기까지의 경기 -> match
## 2016년부터 2020년 7월 19일의 경기까지의 선수 -> player
## 2016년부터 2020년 7월 19일의 경기까지의 등록선수 -> regplayer
## 2016년부터 2020년 7월 19일의 경기까지의 팀-> team
## 2016년부터 2020년 7월 19일의 경기까지의 개인타자-> indhitter
## 2016년부터 2020년 7월 19일의 경기까지의 팀타자-> hitter
## 2016년부터 2020년 7월 19일의 경기까지의 개인투수 -> indpitcher
## 2016년부터 2020년 7월 19일의 경기까지의 팀투수-> pitcher

match = pd.concat([file_dict['match'][2016], file_dict['match'][2017], file_dict['match'][2018], file_dict['match'][2019], file_dict['match'][2020]], ignore_index=True)
player = pd.concat([file_dict['player'][2016], file_dict['player'][2017], file_dict['player'][2018], file_dict['player'][2019], file_dict['player'][2020]], ignore_index=True)
regplayer = pd.concat([file_dict['reg_player'][2016], file_dict['reg_player'][2017], file_dict['reg_player'][2018], file_dict['reg_player'][2019], file_dict['reg_player'][2020]], ignore_index=True)
team = pd.concat([file_dict['team'][2016], file_dict['team'][2017], file_dict['team'][2018], file_dict['team'][2019], file_dict['team'][2020]], ignore_index=True)
indhitter = pd.concat([file_dict['ind_hitter'][2016], file_dict['ind_hitter'][2017], file_dict['ind_hitter'][2018], file_dict['ind_hitter'][2019], file_dict['ind_hitter'][2020]], ignore_index=True)
hitter = pd.concat([file_dict['team_hitter'][2016], file_dict['team_hitter'][2017], file_dict['team_hitter'][2018], file_dict['team_hitter'][2019], file_dict['team_hitter'][2020]], ignore_index=True)
indpitcher = pd.concat([file_dict['ind_pitcher'][2016], file_dict['ind_pitcher'][2017], file_dict['ind_pitcher'][2018], file_dict['ind_pitcher'][2019], file_dict['ind_pitcher'][2020]], ignore_index=True)
pitcher = pd.concat([file_dict['team_pitcher'][2016], file_dict['team_pitcher'][2017], file_dict['team_pitcher'][2018], file_dict['team_pitcher'][2019], file_dict['team_pitcher'][2020]], ignore_index=True)

# %%
# 컬럼 명 재설정
## 데이터 정의서에 나와있는 변수명을 사용함

match.columns =  ['게임키', '일자', '원정팀코드', '홈팀코드', '더블헤더코드', '요일', '구장']
player.columns = ['년도','선수코드','선수명','팀코드','포지션','나이','연봉']
regplayer.columns = ['일자', '팀코드', '선수코드', '등록말소']
team.columns = ['영문팀명', '한글팀명']
indhitter.columns = ['게임키', '일자', '팀코드', '상대팀코드', '더블헤더코드', '초말', '선수코드', '선발', '타순', '타자', '타수', '타점', '득점', '안타', '2루타', '3루타', '홈런', '도루', '도루실패', '희타', '희비', '4구', '고4', '사구', '삼진', '병살타', '실책', '잔루', '득점권타율', '득점권타수', '득점권안타']
hitter.columns = ['게임키', '일자', '팀코드', '상대팀코드', '더블헤더코드', '초말', '타자_h', '타수_h', '타점_h', '득점_h', '안타_h', '2루타_h', '3루타_h', '홈런_h', '도루_h', '도루실패_h', '희타_h', '희비_h', '4구_h', '고4_h', '사구_h', '삼진_h', '병살타_h', '실책_h', '잔루_h', '득점권타율_h', '득점권타수_h', '득점권안타_h']
indpitcher.columns = ['게임키', '일자', '팀코드', '상대팀코드', '더블헤더코드', '초말', '선수코드', '선발', '구원', '완투', '종료', '결과', '홀드', '이닝*3', '투구수', '타자', '타수', '안타', '2루타', '3루타', '홈런', '도루', '도루실패', '희타', '희비', '4구', '고4', '사구', '삼진', '병살타', '폭투', '보크', '실책', '실점', '자책점', '득점권WHIP', '2점차이하WHIP', '345번타자WHIP']
pitcher.columns = ['게임키', '일자', '팀코드', '상대팀코드', '더블헤더코드', '초말', '완투_p', '결과_p', '홀드_p', '이닝*3_p', '투구수_p', '타자_p', '타수_p', '안타_p', '2루타_p', '3루타_p', '홈런_p', '도루_p', '도루실패_p', '희타_p', '희비_p', '4구_p', '고4_p', '사구_p', '삼진_p', '병살타_p', '폭투_p', '보크_p', '실책_p', '실점_p', '자책점_p', '득점권WHIP_p', '2점차이하WHIP_p', '345번타자WHIP_p']

# %%
# 팀명 대문자로 변경

regplayer['팀코드'] = regplayer['팀코드'].str.upper()
player['팀코드'] = player['팀코드'].str.upper()
match['원정팀코드'] = match['원정팀코드'].str.upper()
match['홈팀코드'] = match['홈팀코드'].str.upper()

# %%
# KBO 공식 홈페이지

# 전년도승률데이터셋
## 2015년 ~ 2019년 각 팀의 승률
before_WR={'팀코드':['OB','SS','NC','WO','SK','HH','HT','LT','LG','KT','HT','OB','LT','NC','SK','LG','WO','HH','SS','KT','HT','OB','LT','NC','SK','LG','WO','HH','SS','KT','HT','OB','LT','NC','SK','LG','WO','HH','SS','KT','HT','OB','LT','NC','SK','LG','WO','HH','SS','KT'],
           '년도':[2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019],
           '승률':[0.549, 0.611, 0.596, 0.545, 0.486, 0.472, 0.465, 0.462, 0.451, 0.364, 0.49, 0.65, 0.458, 0.589, 0.479, 0.5, 0.538, 0.468, 0.455, 0.373, 0.608, 0.596, 0.563, 0.56, 0.524, 0.489, 0.486, 0.43, 0.396, 0.347, 0.486, 0.646, 0.479, 0.406, 0.545, 0.476, 0.521, 0.535, 0.486, 0.418, 0.437, 0.615, 0.34, 0.514, 0.615, 0.552, 0.601, 0.403, 0.42, 0.5]}

# 전년도 상대 승률 데이터셋
## 2015년 ~ 2019년 각 팀별 상대 승률
beforeVsWR15 = {'팀코드' : ['HH', 'HH', 'HH', 'HH', 'HH', 'HH', 'HH', 'HH', 'HH', 'HT', 'HT', 'HT', 'HT', 'HT', 'HT', 'HT', 'HT', 'HT', 'KT', 'KT', 'KT', 'KT', 'KT', 'KT', 'KT', 'KT', 'KT', 'LG', 'LG', 'LG', 'LG', 'LG', 'LG', 'LG', 'LG', 'LG', 'LT', 'LT', 'LT', 'LT', 'LT', 'LT', 'LT', 'LT', 'LT', 'NC', 'NC', 'NC', 'NC', 'NC', 'NC', 'NC', 'NC', 'NC', 'OB', 'OB', 'OB', 'OB', 'OB', 'OB', 'OB', 'OB', 'OB', 'SK', 'SK', 'SK', 'SK', 'SK', 'SK', 'SK', 'SK', 'SK', 'SS', 'SS', 'SS', 'SS', 'SS', 'SS', 'SS', 'SS', 'SS', 'WO', 'WO', 'WO', 'WO', 'WO', 'WO', 'WO', 'WO', 'WO'],
                '상대팀코드' : ['HT', 'KT', 'LG', 'LT', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'KT', 'LG', 'LT', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'LG', 'LT', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LT', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'NC', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'NC', 'OB', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'NC', 'OB', 'SK', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'NC', 'OB', 'SK', 'SS'],
                '년도' : [2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015,  2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015],
                 '상대승률' : [0.4375,0.5625,0.5625,0.5,0.3125,0.4375,0.4375,0.625,0.375,0.4375,0.5625,0.4375,0.4375,0.3125,0.5,0.625,0.5,0.25,0.4375,0.4375,0.5,0.375,0.333333333,0.25,0.4375,0.1875,0.3125,0.4375,0.5625,0.5,0.4,0.666666667,0.5,0.3125,0.3125,0.375,0.5,0.5625,0.625,0.6,0.3125,0.375,0.375,0.375,0.4375,0.6875,0.6875,0.666666667,0.333333333,0.6875,0.5,0.666666667,0.3125,0.8125,0.5625,0.5,0.75,0.5,0.625,0.5,0.6875,0.3125,0.5,0.5625,0.375,0.5625,0.6875,0.625,0.333333333,0.3125,0.4375,0.466666667,0.375,0.5,0.8125,0.6875,0.625,0.6875,0.6875,0.5625,0.5625,0.625,0.75,0.6875,0.625,0.5625,0.1875,0.5,0.533333333,0.4375]}

beforeVsWR16 = {'팀코드' : ['HH', 'HH', 'HH', 'HH', 'HH', 'HH', 'HH', 'HH', 'HH', 'HT', 'HT', 'HT', 'HT', 'HT', 'HT', 'HT', 'HT', 'HT', 'KT', 'KT', 'KT', 'KT', 'KT', 'KT', 'KT', 'KT', 'KT', 'LG', 'LG', 'LG', 'LG', 'LG', 'LG', 'LG', 'LG', 'LG', 'LT', 'LT', 'LT', 'LT', 'LT', 'LT', 'LT', 'LT', 'LT', 'NC', 'NC', 'NC', 'NC', 'NC', 'NC', 'NC', 'NC', 'NC', 'OB', 'OB', 'OB', 'OB', 'OB', 'OB', 'OB', 'OB', 'OB', 'SK', 'SK', 'SK', 'SK', 'SK', 'SK', 'SK', 'SK', 'SK', 'SS', 'SS', 'SS', 'SS', 'SS', 'SS', 'SS', 'SS', 'SS', 'WO', 'WO', 'WO', 'WO', 'WO', 'WO', 'WO', 'WO', 'WO'],
                '상대팀코드' : ['HT', 'KT', 'LG', 'LT', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'KT', 'LG', 'LT', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'LG', 'LT', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LT', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'NC', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'NC', 'OB', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'NC', 'OB', 'SK', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'NC', 'OB', 'SK', 'SS'],
                '년도' : [2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016,
                        2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016,2016, 2016],
                                '상대승률' : [ 0.4375, 0.466666667,0.4375, 0.533333333 , 0.466666667 , 0.25, 0.6875, 0.666666667, 0.3125, 0.5625, 0.6875, 0.466666667, 0.625, 0.4375, 0.3125, 0.5, 0.5, 0.3125, 0.533333333, 0.3125, 0.375, 0.375, 0.4, 0.1875, 0.4375, 0.5, 0.25, 0.5625, 0.533333333, 0.625, 0.5, 0.4, 0.4375, 0.375, 0.4375, 0.625, 0.5, 0.375, 0.625, 0.5, 0.0625, 0.5, 0.4375, 0.6875, 0.4375, 0.533333333, 0.5625, 0.6, 0.6, 0.9375, 0.4375, 0.625, 0.5, 0.5, 0.75, 0.6875, 0.8125, 0.5625, 0.5, 0.5625, 0.75, 0.625, 0.6, 0.3125, 0.5, 0.5625, 0.625, 0.5625, 0.375, 0.25, 0.5, 0.625, 0.333333333, 0.5, 0.5, 0.5625, 0.3125, 0.5, 0.375, 0.5, 0.5, 0.6875, 0.6875, 0.75, 0.375, 0.5625, 0.5, 0.4, 0.375, 0.5]}

beforeVsWR17 = {'팀코드' : ['HH', 'HH', 'HH', 'HH', 'HH', 'HH', 'HH', 'HH', 'HH', 'HT', 'HT', 'HT', 'HT', 'HT', 'HT', 'HT', 'HT', 'HT', 'KT', 'KT', 'KT', 'KT', 'KT', 'KT', 'KT', 'KT', 'KT', 'LG', 'LG', 'LG', 'LG', 'LG', 'LG', 'LG', 'LG', 'LG', 'LT', 'LT', 'LT', 'LT', 'LT', 'LT', 'LT', 'LT', 'LT', 'NC', 'NC', 'NC', 'NC', 'NC', 'NC', 'NC', 'NC', 'NC', 'OB', 'OB', 'OB', 'OB', 'OB', 'OB', 'OB', 'OB', 'OB', 'SK', 'SK', 'SK', 'SK', 'SK', 'SK', 'SK', 'SK', 'SK', 'SS', 'SS', 'SS', 'SS', 'SS', 'SS', 'SS', 'SS', 'SS', 'WO', 'WO', 'WO', 'WO', 'WO', 'WO', 'WO', 'WO', 'WO'],
                '상대팀코드' : ['HT', 'KT', 'LG', 'LT', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'KT', 'LG', 'LT', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'LG', 'LT', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LT', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'NC', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'NC', 'OB', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'NC', 'OB', 'SK', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'NC', 'OB', 'SK', 'SS'],
                '년도' : [2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017,
                        2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017 ],
                '상대승률' : [0.3125,0.75,0.5625,0.3125,0.4,0.4375,0.3125,0.4,0.375,0.6875,0.625,0.625,0.5625,0.5625,0.466666667,0.5625,0.75,0.625,0.25,0.375,0.3125,0.3125,0.25,0.3125,0.4375,0.5,0.375,0.4375,0.375,0.6875,0.466666667,0.3125,0.4,0.4375,0.625,0.666666667,0.6875,0.4375,0.6875,0.533333333,0.5625,0.5,0.5625,0.466666667,0.625,0.6,0.4375,0.75,0.6875,0.4375,0.3125,0.5625,0.5,0.75,0.5625,0.533333333,0.6875,0.6,0.5,0.6875,0.5,0.8,0.5,0.6875,0.4375,0.5625,0.5625,0.4375,0.4375,0.5,0.6875,0.4,0.6,0.25,0.5,0.375,0.533333333,0.5,0.2,0.3125,0.3125,0.625,0.375,0.625,0.333333333,0.375,0.25,0.5,0.6,0.6875]}


beforeVsWR18 = {'팀코드' : ['HH', 'HH', 'HH', 'HH', 'HH', 'HH', 'HH', 'HH', 'HH', 'HT', 'HT', 'HT', 'HT', 'HT', 'HT', 'HT', 'HT', 'HT', 'KT', 'KT', 'KT', 'KT', 'KT', 'KT', 'KT', 'KT', 'KT', 'LG', 'LG', 'LG', 'LG', 'LG', 'LG', 'LG', 'LG', 'LG', 'LT', 'LT', 'LT', 'LT', 'LT', 'LT', 'LT', 'LT', 'LT', 'NC', 'NC', 'NC', 'NC', 'NC', 'NC', 'NC', 'NC', 'NC', 'OB', 'OB', 'OB', 'OB', 'OB', 'OB', 'OB', 'OB', 'OB', 'SK', 'SK', 'SK', 'SK', 'SK', 'SK', 'SK', 'SK', 'SK', 'SS', 'SS', 'SS', 'SS', 'SS', 'SS', 'SS', 'SS', 'SS', 'WO', 'WO', 'WO', 'WO', 'WO', 'WO', 'WO', 'WO', 'WO'],
                '상대팀코드' : ['HT', 'KT', 'LG', 'LT', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'KT', 'LG', 'LT', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'LG', 'LT', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LT', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'NC', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'NC', 'OB', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'NC', 'OB', 'SK', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'NC', 'OB', 'SK', 'SS'],
                '년도' : [2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 
                        2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018],
                '상대승률' : [0.5625,0.625,0.5625,0.625,0.5625,0.5,0.3125,0.5625,0.5,0.4375,0.5625,0.4375,0.375,0.4375,0.5,0.6875,0.375,0.5625,0.375,0.4375,0.4375,0.266666667,0.6875,0.4375,0.3125,0.5,0.3125,0.4375,0.5625,0.5625,0.533333333,0.5,0.0625,0.375,0.5625,0.6875,0.375,0.625,0.733333333,0.466666667,0.5625,0.1875,0.5625,0.25,0.5625,0.4375,0.5625,0.3125,0.5,0.4375,0.25,0.3125,0.4,0.4375,0.5,0.5,0.5625,0.9375,0.8125,0.75,0.5,0.75,0.5,0.6875,0.3125,0.6875,0.625,0.4375,0.6875,0.5,0.5,0.4375,0.4375,0.625,0.5,0.4375,0.75,0.6,0.25,0.466666667,0.3125,0.5,0.4375,0.6875,0.3125,0.4375,0.5625,0.5,0.5625,0.6875]}


beforeVsWR19 = {'팀코드' : ['HH', 'HH', 'HH', 'HH', 'HH', 'HH', 'HH', 'HH', 'HH', 'HT', 'HT', 'HT', 'HT', 'HT', 'HT', 'HT', 'HT', 'HT', 'KT', 'KT', 'KT', 'KT', 'KT', 'KT', 'KT', 'KT', 'KT', 'LG', 'LG', 'LG', 'LG', 'LG', 'LG', 'LG', 'LG', 'LG', 'LT', 'LT', 'LT', 'LT', 'LT', 'LT', 'LT', 'LT', 'LT', 'NC', 'NC', 'NC', 'NC', 'NC', 'NC', 'NC', 'NC', 'NC', 'OB', 'OB', 'OB', 'OB', 'OB', 'OB', 'OB', 'OB', 'OB', 'SK', 'SK', 'SK', 'SK', 'SK', 'SK', 'SK', 'SK', 'SK', 'SS', 'SS', 'SS', 'SS', 'SS', 'SS', 'SS', 'SS', 'SS', 'WO', 'WO', 'WO', 'WO', 'WO', 'WO', 'WO', 'WO', 'WO'],
                '상대팀코드' : ['HT', 'KT', 'LG', 'LT', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'KT', 'LG', 'LT', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'LG', 'LT', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LT', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'NC', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'OB', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'NC', 'SK', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'NC', 'OB', 'SS', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'NC', 'OB', 'SK', 'WO', 'HH', 'HT', 'KT', 'LG', 'LT', 'NC', 'OB', 'SK', 'SS'],
                '년도' : [2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 
                        2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019],
                '상대승률' : [0.25,0.5,0.4375,0.5,0.4375,0.375,0.25,0.375,0.5,0.75,0.25,0.375,0.5625,0.4375,0.1875,0.533333333,0.5,0.333333333,0.5,0.75,0.1875,0.785714286,0.375,0.5625,0.375,0.5625,0.4375,0.5625,0.625,0.8125,0.666666667,0.5,0.375,0.375,0.625,0.4375,0.5,0.4375,0.214285714,0.333333333,0.3125,0.3125,0.1875,0.5625,0.1875,0.5625,0.5625,0.625,0.5,0.6875,0.466666667,0.4375,0.4,0.375,0.625,0.8125,0.4375,0.625,0.6875,0.533333333,0.5625,0.8125,0.4375,0.75,0.466666667,0.625,0.625,0.8125,0.5625,0.4375,0.75,0.5, 0.625,0.5, 0.4375 ,0.375,0.4375, 0.6 ,0.1875,0.25,0.375,0.5,0.666666667,0.5625,0.5625,0.8125,0.625,0.5625,0.5,0.625] } 

before_WR=pd.DataFrame(before_WR)

beforeVsWR15=pd.DataFrame(beforeVsWR15)
beforeVsWR16=pd.DataFrame(beforeVsWR16)
beforeVsWR17=pd.DataFrame(beforeVsWR17)
beforeVsWR18=pd.DataFrame(beforeVsWR18)
beforeVsWR19=pd.DataFrame(beforeVsWR19)

before_VSWR=pd.concat([beforeVsWR15,beforeVsWR16,beforeVsWR17,beforeVsWR18,beforeVsWR19],ignore_index=True)

# %% [markdown]
# ---
#
# ## 4.2 데이터 확인하기

# %% [markdown]
# ### 4.2.3 player
# 선수.csv

# %%
player.head(3)
# Out:
#      년도   선수코드  선수명 팀코드 포지션  나이      연봉
# 0  2016  60100  백창수  LG   내  28  4000만원
# 1  2016  60105  배민관  LG   투  25  2700만원
# 2  2016  60146  이승현  LG   투  25  3700만원

# %%
player.shape
# Out:
# (3271, 7)

# %% [markdown]
# ### 4.2.4 pitcher
# 팀투수.csv

# %%
pitcher.head(3)
# Out:
#              게임키        일자 팀코드 상대팀코드  더블헤더코드 초말  완투_p 결과_p  홀드_p  이닝*3_p  \
# 0  20160401HHLG0  20160401  LG    HH       0  B     0    W     0      36
# 1  20160401HHLG0  20160401  HH    LG       0  T     0    L     0      34
# 2  20160401HTNC0  20160401  NC    HT       0  B     0    W     0      27
#
#    투구수_p  타자_p  타수_p  안타_p  2루타_p  3루타_p  홈런_p  도루_p  도루실패_p  희타_p  희비_p  \
# 0    184    52    46    13      2      0     0     0       0     3     0
# 1    196    47    42     9      2      0     1     2       1     1     0
# 2    143    38    34     8      3      0     1     0       0     0     0
#
#    4구_p  고4_p  사구_p  삼진_p  병살타_p  폭투_p  보크_p  실책_p  실점_p  자책점_p  득점권WHIP_p  \
# 0     3     0     0    10      1     0     0     0     4      4   0.642857
# 1     4     0     0    11      0     1     0     0     5      4   1.500000
# 2     3     0     1    10      1     2     0     0     4      4   1.333333
#
#    2점차이하WHIP_p  345번타자WHIP_p
# 0     1.285714      2.400000
# ...

# %%
pitcher.shape
# Out:
# (6400, 34)

# %% [markdown]
# ### 4.2.5 hitter
# 팀타자.csv

# %%
hitter.head(3)
# Out:
#              게임키        일자 팀코드 상대팀코드  더블헤더코드 초말  타자_h  타수_h  타점_h  득점_h  안타_h  \
# 0  20160401HHLG0  20160401  LG    HH       0  B    47    42     4     5     9
# 1  20160401HHLG0  20160401  HH    LG       0  T    52    46     4     4    13
# 2  20160401HTNC0  20160401  NC    HT       0  B    36    30     5     5     9
#
#    2루타_h  3루타_h  홈런_h  도루_h  도루실패_h  희타_h  희비_h  4구_h  고4_h  사구_h  삼진_h  \
# 0      2      0     1     2       1     1     0     4     0     0    11
# 1      2      0     0     0       0     3     0     3     0     0    10
# 2      2      0     2     0       0     1     0     5     0     0     9
#
#    병살타_h  실책_h  잔루_h   득점권타율_h  득점권타수_h  득점권안타_h
# 0      0     0     8  0.333333       12        4
# 1      1     2    12  0.200000       15        3
# 2      1     1     7  0.142857        7        1

# %%
hitter.shape
# Out:
# (6400, 28)

# %% [markdown]
# ### 4.2.6 team_p_h
# 팀투수.csv + 팀타자.csv

# %%
# pitcher 와 hitter를 합친 데이터 셋 생성
team_p_h = pd.merge(hitter, pitcher, on = ['게임키', '일자', '팀코드', '상대팀코드', '더블헤더코드', '초말'])

# %% [markdown]
# ## 4.3 그래프로 확인하기

# %% [markdown]
# ### 4.3.1 팀별 경기수
# 야구 경기에 참여하는 팀은 총 10팀으로 경기 수는 모두 비슷하다.

# %%
sns.countplot("팀코드", data = pitcher)

# %% [markdown]
# ### 4.3.2 팀별 경기 결과
# 팀 LG, NV, HT, SK, WO, OB는 승리의 횟수가 패배의 횟수보다 많다.

# %%
sns.countplot("팀코드", hue = '결과_p' , data = pitcher)

# %% [markdown]
# ### 4.3.3 팀별 선수들의 나이 상자그림
# 역대 팀 WO의 역대 나이가 비교적 적고, 팀 HH의 선수들의 나이가 많다.

# %%
plt.xticks(rotation=45)
sns.boxplot(x="팀코드", y="나이", data=player, palette="Paired")

# %% [markdown]
# ---
#
# # 5. 피처 엔지니어링(Feature Engineering)

# %% [markdown]
# ---
#
# ## 5.1 결측치 확인 & 처리

# %% [markdown]
# **player**

# %%
player.isnull().sum()
# Out:
# 년도      0
# 선수코드    0
# 선수명     0
# 팀코드     0
# 포지션     0
# 나이      0
# 연봉      1
# dtype: int64

# %%
player[player['연봉'].isnull()]
# Out:
#       년도   선수코드  선수명 팀코드 포지션  나이   연봉
# 95  2016  62322  밴헤켄  WO   투  37  NaN

# %%
player = player.dropna()

# %% [markdown]
# **pitcher**

# %%
pitcher.isnull().sum()
# Out:
# 게임키             0
# 일자              0
# 팀코드             0
# 상대팀코드           0
# 더블헤더코드          0
# 초말              0
# 완투_p            0
# 결과_p            0
# 홀드_p            0
# 이닝*3_p          0
# 투구수_p           0
# 타자_p            0
# 타수_p            0
# 안타_p            0
# 2루타_p           0
# 3루타_p           0
# 홈런_p            0
# 도루_p            0
# 도루실패_p          0
# 희타_p            0
# 희비_p            0
# 4구_p            0
# 고4_p            0
# 사구_p            0
# 삼진_p            0
# 병살타_p           0
# 폭투_p            0
# 보크_p            0
# 실책_p            0
# 실점_p            0
# 자책점_p           0
# 득점권WHIP_p       0
# 2점차이하WHIP_p     0
# 345번타자WHIP_p    0
# dtype: int64

# %% [markdown]
# **hitter**

# %%
hitter.isnull().sum()
# Out:
# 게임키        0
# 일자         0
# 팀코드        0
# 상대팀코드      0
# 더블헤더코드     0
# 초말         0
# 타자_h       0
# 타수_h       0
# 타점_h       0
# 득점_h       0
# 안타_h       0
# 2루타_h      0
# 3루타_h      0
# 홈런_h       0
# 도루_h       0
# 도루실패_h     0
# 희타_h       0
# 희비_h       0
# 4구_h       0
# 고4_h       0
# 사구_h       0
# 삼진_h       0
# 병살타_h      0
# 실책_h       0
# 잔루_h       0
# 득점권타율_h    0
# 득점권타수_h    0
# 득점권안타_h    0
# dtype: int64

# %% [markdown]
# ## 5.2 승률 새로운 피처 생성

# %% [markdown]
# **5.2.1 player 관련**

# %%
player_age = player[['년도','팀코드','나이']]
player_money = player[['년도','팀코드','연봉']]

# %% [markdown]
# **5.2.1.1 연봉 피처 생성**

# %%
# 선수마다 받은 연봉의 화폐가 다르므로, '원 (won)'을 기준으로 변환시켰음
## 2020년 08월 29일 기준 환율을 적용해서 계산

jpy = player_money[player_money['연봉'].str.contains('엔')]
jpy['연봉'] = jpy['연봉'].str.replace('엔','')
jpy['연봉'] = pd.to_numeric(jpy['연봉'])
jpy['연봉'] = (jpy['연봉']/100)*1122.87/10000

usd = player_money[player_money['연봉'].str.contains('달러')]
usd['연봉'] = usd['연봉'].str.replace('달러','')
usd['연봉'] = pd.to_numeric(usd['연봉'])
usd['연봉'] = usd['연봉']*1183/10000

krw = player_money[player_money['연봉'].str.contains('만원')]
krw['연봉'] = krw['연봉'].str.replace('만원','')
krw['연봉'] = pd.to_numeric(krw['연봉'])

player_money = pd.concat([jpy,usd,krw],ignore_index=True)

# %%
player_age = player_age.groupby(['년도','팀코드'],as_index=False).mean()
player_money = player_money.groupby(['년도','팀코드'],as_index=False).mean()
player = pd.merge(player_age,player_money,left_on = ['년도','팀코드'],right_on = ['년도','팀코드'],how='left')

# %%
player.head()
# Out:
#      년도 팀코드         나이            연봉
# 0  2016  HH  29.229730  20037.329730
# 1  2016  HT  27.373134  16210.298507
# 2  2016  KT  27.061538  11489.246154
# 3  2016  LG  27.939394  14245.833333
# 4  2016  LT  27.400000  15891.242857

# %% [markdown]
# **->** 각 팀에 대해서, 년도별 팀내 선수들의 평균 나이와 연봉을 나타냄

# %% [markdown]
# **5.2.2 pitcher관련**

# %% [markdown]
# **5.2.2.1 년도 피처 생성**

# %%
# 년도 추가하기
def year(c):
    if c['일자'] > 20160000 and c['일자'] < 20170000:
        return 2016
    elif c['일자'] > 20170000 and c['일자'] < 20180000:
        return 2017
    elif c['일자'] > 20180000 and c['일자'] < 20190000:
        return 2018
    elif c['일자'] > 20190000 and c['일자'] < 20200000:
        return 2019
    else:
        return 2020
    
pitcher['년도'] = pitcher.apply(year,axis=1)
hitter['년도'] = hitter.apply(year,axis=1)

# %% [markdown]
# **5.2.2.2 기타 피처 생성**
# 피안타율, 평균자책점, WHIP, 실점/이닝, 삼진/볼넷, 볼넷/이닝, 삼진/이닝, 피홈런/이닝, 타자/이닝

# %%
# 피안타율계산
def OAVG(x):
    if x['타수_p']>0:
        return x['안타_p']/x['타수_p']
    elif x['안타_p']==0:
        return 0
    else:
        return 99.9
    
# 평균자책점
def ERA(x):
    if(x['이닝*3_p']>0):
        return x['자책점_p']/(x['이닝*3_p']/3)*9
    elif x['자책점_p']==0:
        return 0
    else:
        return 99.9

# WHIP = 안타+4구/이닝수
#고의사구 포함
#사구는 제외
def WHIP(x):
    H = x['안타_p']+x['2루타_p']+x['3루타_p']+x['홈런_p']
    B=x['4구_p']+x['고4_p']
    HB=H+B
    if(x['이닝*3_p']>0):
        return HB/(x['이닝*3_p']/3)*9
    elif HB==0:
        return 0
    else:
        return 99.9
    
# RA9 = 실점/이닝수*9
#비자책과 자책 구분하지 않은 평균 실점
def RA9(x):
    if(x['이닝*3_p']>0):
        return x['실점_p']/(x['이닝*3_p']/3)*9
    elif x['실점_p']==0:
        return 0
    else:
        return 99.9
    
# K_B = 삼진/볼넷
#이게 우수한 타자가 ERA도 우수할 가능성이 높다. ( 가정)
def K_B(x):
    if x['4구_p']>0:
        return x['삼진_p']/x['4구_p']
    elif x['삼진_p']==0:
        return 0
    else:
        return 99.9
    
# 볼넷/이닝
def BALL(x):
    if(x['이닝*3_p']>0):
        return x['4구_p']/(x['이닝*3_p']/3)*9
    elif x['4구_p']==0:
        return 0
    else:
        return 99.9
    
# 삼진/이닝
def KKK(x):
    if(x['이닝*3_p']>0):
        return x['삼진_p']/(x['이닝*3_p']/3)*9
    elif x['삼진_p']==0:
        return 0
    else:
        return 99.9
    
# 피홈런/이닝
def HR(x):
    if(x['이닝*3_p']>0):
        return x['홈런_p']/(x['이닝*3_p']/3)*9
    elif x['홈런_p']==0:
        return 0
    else:
        return 99.9
    
# 타자/이닝
def HITTER(x):
    if(x['이닝*3_p']>0):
        return x['타자_p']/(x['이닝*3_p']/3)*9
    elif x['타자_p']==0:
        return 0
    else:
        return 99.9
    
pitcher['피안타율_p']=pitcher.apply(OAVG,axis=1)
pitcher['평균자책점_p']=pitcher.apply(ERA,axis=1)
pitcher['실점/이닝_p']=pitcher.apply(RA9,axis=1)
pitcher['삼진/이닝_p']=pitcher.apply(KKK,axis=1)
pitcher['볼넷/이닝_p']=pitcher.apply(BALL,axis=1)
pitcher['삼진/볼넷_p']=pitcher.apply(K_B,axis=1)
pitcher['피홈런/이닝_p']=pitcher.apply(HR,axis=1)
pitcher['타자/이닝_p']=pitcher.apply(HITTER,axis=1)
pitcher['WHIP_p']=pitcher.apply(WHIP,axis=1)

# %%
pitcher = pitcher.loc[:,['게임키','년도','일자','팀코드','상대팀코드','결과_p','피안타율_p','평균자책점_p','실점/이닝_p','볼넷/이닝_p','삼진/볼넷_p','피홈런/이닝_p','타자/이닝_p','WHIP_p']]

# %%
pitcher.head(3)
# Out:
#              게임키    년도        일자 팀코드 상대팀코드 결과_p    피안타율_p   평균자책점_p   실점/이닝_p  \
# 0  20160401HHLG0  2016  20160401  LG    HH    W  0.282609  3.000000  3.000000
# 1  20160401HHLG0  2016  20160401  HH    LG    L  0.214286  3.176471  3.970588
# 2  20160401HTNC0  2016  20160401  NC    HT    W  0.235294  4.000000  4.000000
#
#     볼넷/이닝_p   삼진/볼넷_p  피홈런/이닝_p    타자/이닝_p     WHIP_p
# 0  2.250000  3.333333  0.000000  39.000000  13.500000
# 1  3.176471  2.750000  0.794118  37.323529  12.705882
# 2  3.000000  3.333333  1.000000  38.000000  15.000000

# %% [markdown]
# **->** 각 경기에 대한, 팀( 팀코드 )의 일자에 해당하는 경기 결과와 경기의 피안타율, 평균자책점, 실점/이닝, 삼진/볼넷, 피홈런/이닝, 타자/이닝, WHIP

# %% [markdown]
# **5.2.3 hitter관련**
# 출루율, 장타율, 타율, 사구/타수, 삼진/타수

# %%
# 출루율
def chulru(x):
    if((x['타수_h']+x['사구_h']+x['4구_h'])>0):
        return (x['안타_h']+x['사구_h']+x['4구_h'])/(x['타수_h']+x['사구_h']+x['4구_h'])
    elif (x['타수_h']+x['사구_h']+x['4구_h'])==0:
        return 0
    else:
        return 99.9
    
# 장타율
def jangta(x):
    if(x['타수_h']>0):
        return (x['안타_h']+x['2루타_h']+x['3루타_h']*2+x['홈런_h']*3)/x['타수_h']
    elif x['타수_h']==0:
        return 0
    else:
        return 99.9
        
# 타율
def ta(x):
    if(x['타수_h']>0):
        return x['안타_h']/x['타수_h']
    elif x['타수_h']==0:
        return 0
    else:
        return 99.9
    
# 사구/타수
def sagu(x):
    if(x['타수_h']>0):
        return (x['사구_h']+x['4구_h'])/x['타수_h']
    elif x['타수_h']==0:
        return 0
    else:
        return 99.9
    
# 삼진/타수
def samjin(x):
    if(x['타수_h']>0):
        return x['삼진_h']/x['타수_h']
    elif x['타수_h']==0:
        return 0
    else:
        return 99.9
    
hitter['출루율_h']=hitter.apply(chulru,axis=1)
hitter['장타율_h']=hitter.apply(jangta,axis=1)
hitter['타율_h']=hitter.apply(ta,axis=1)
hitter['사구/타수_h']=hitter.apply(sagu,axis=1)
hitter['삼진/타수_h']=hitter.apply(samjin,axis=1)

# %%
hitter = hitter.loc[:,['게임키','년도','일자','팀코드','상대팀코드','득점권타율_h','출루율_h','장타율_h','타율_h','사구/타수_h','삼진/타수_h']]

# %%
hitter.head(3)
# Out:
#              게임키    년도        일자 팀코드 상대팀코드   득점권타율_h     출루율_h     장타율_h  \
# 0  20160401HHLG0  2016  20160401  LG    HH  0.333333  0.282609  0.333333
# 1  20160401HHLG0  2016  20160401  HH    LG  0.200000  0.326531  0.326087
# 2  20160401HTNC0  2016  20160401  NC    HT  0.142857  0.400000  0.566667
#
#        타율_h   사구/타수_h   삼진/타수_h
# 0  0.214286  0.095238  0.261905
# 1  0.282609  0.065217  0.217391
# 2  0.300000  0.166667  0.300000

# %% [markdown]
# **->** 각 경기에 대한,  팀( 팀코드 팀 )의 상대팀에 대한 득점권타율, 출루율, 장타율, 타율, 사구/타수, 삼진/타수

# %%
# pitcher,와 hitter 그리고 player를 합친 데이터 셋 생성
DATA=pd.merge(pitcher,hitter,left_on=['게임키','일자','팀코드','상대팀코드','년도'],right_on=['게임키','일자','팀코드','상대팀코드','년도'],how='left')
DATA=pd.merge(DATA,player,left_on=['년도','팀코드'],right_on=['년도','팀코드'],how='left')

# %%
# 시즌 생성 ( 올스타전 날짜 기준)
## 2016년~2019년 : 올스타전 기준 전경기들 -> 상반기 경기
## 2016년~2019년 : 올스타전 기준 전경기들 -> 하반기 경기
## 2020년의 경우, 코로나로 인해 올스타전 취소 
## 2020년 7월 20일 이전 경기 -> 상반기 경기
## 2020년 7월 20일 이후의 경기 -> 하반기 경기

def season(x):
    if (x['일자'] > 20160000 and x['일자'] < 20160714) or (x['일자'] > 20170000 and x['일자'] < 20170713) or (x['일자'] > 20180000 and x['일자'] < 20180712) or (x['일자'] > 20190000 and x['일자'] < 20190718) or (x['일자'] > 20200000 and x['일자'] < 20200720):
        return '상'
    else:
        return '하'
    
DATA['상/하']=DATA.apply(season,axis=1)

def OBS(x):
    return (x['팀코드']+x['상대팀코드']+str(x['년도'])+x['상/하'])

DATA['OBS']=DATA.apply(OBS,axis=1)

#전년도 승률과 상대승률 합치기
before_WR['년도']=before_WR['년도']+1
DATA=pd.merge(DATA,before_WR,left_on=['팀코드','년도'],right_on=['팀코드','년도'],how='left')
DATA.rename(columns={'승률':'전년도승률'},inplace=True)

before_VSWR.rename(columns={'시즌':'년도'},inplace=True)
before_VSWR['년도']=before_VSWR['년도']+1
DATA=pd.merge(DATA,before_VSWR,left_on=['팀코드','상대팀코드','년도'],right_on=['팀코드','상대팀코드','년도'],how='left')
DATA.rename(columns={'상대승률':'전년도상대승률'},inplace=True)

# %%
DATA.head(3)
# Out:
#              게임키    년도        일자 팀코드 상대팀코드 결과_p    피안타율_p   평균자책점_p   실점/이닝_p  \
# 0  20160401HHLG0  2016  20160401  LG    HH    W  0.282609  3.000000  3.000000
# 1  20160401HHLG0  2016  20160401  HH    LG    L  0.214286  3.176471  3.970588
# 2  20160401HTNC0  2016  20160401  NC    HT    W  0.235294  4.000000  4.000000
#
#     볼넷/이닝_p   삼진/볼넷_p  피홈런/이닝_p    타자/이닝_p     WHIP_p   득점권타율_h     출루율_h  \
# 0  2.250000  3.333333  0.000000  39.000000  13.500000  0.333333  0.282609
# 1  3.176471  2.750000  0.794118  37.323529  12.705882  0.200000  0.326531
# 2  3.000000  3.333333  1.000000  38.000000  15.000000  0.142857  0.400000
#
#       장타율_h      타율_h   사구/타수_h   삼진/타수_h         나이            연봉 상/하  \
# 0  0.333333  0.214286  0.095238  0.261905  27.939394  14245.833333   상
# 1  0.326087  0.282609  0.065217  0.217391  29.229730  20037.329730   상
# 2  0.566667  0.300000  0.166667  0.300000  25.940299  13309.029851   상
#
#          OBS  전년도승률  전년도상대승률
# 0  LGHH2016상  0.451   0.4375
# ...

# %% [markdown]
# ## 5.3 타율 & 방어율 새 피처 추가

# %%
# 년도 추가하기
team_p_h['년도'] = team_p_h.apply(year,axis=1)

# 상/하 추가하기
team_p_h['상/하']=team_p_h.apply(season,axis=1)

# %% [markdown]
# **5.3.1 pitcher 관련**
# 피안타율, 평균자책점, WHIP, 실점/이닝, 삼진/볼넷, 볼넷/이닝, 삼진/이닝, 피홈런/이닝, 타자/이닝

# %%
# 피안타율계산
team_p_h['피안타율_p'] = team_p_h.apply(OAVG,axis=1)

# 평균자책점
team_p_h['평균자책점_p'] = team_p_h.apply(ERA,axis=1)

# RA9 = 실점/이닝수*9
# 비자책과 자책 구분하지 않은 평균 실점
team_p_h['실점/이닝_p'] = team_p_h.apply(RA9,axis=1)

# 삼진/이닝
team_p_h['삼진/이닝_p'] = team_p_h.apply(KKK,axis=1)

# 볼넷/이닝
team_p_h['볼넷/이닝_p'] = team_p_h.apply(BALL,axis=1)

# K_B = 삼진 / 볼넷
# 이게 우수한 타자가 ERA도 우수할 가능성이 높다
team_p_h['삼진/볼넷_p'] = team_p_h.apply(K_B,axis=1)

# 피홈런/이닝
team_p_h['피홈런/이닝_p'] = team_p_h.apply(HR,axis=1)

#타자/이닝
team_p_h['타자/이닝_p'] = team_p_h.apply(HITTER,axis=1)

# WHIP=안타+4구/이닝수
# 고의사구 포함
# 사구는 제외
team_p_h['WHIP_p'] = team_p_h.apply(WHIP,axis=1)

# %% [markdown]
# **5.2.2 hitter 관련**
# 출루율, 장타율, 타율, 사구/타수, 삼진/타수

# %%
# 출루율
team_p_h['출루율_h'] = team_p_h.apply(chulru,axis=1)

# 장타율
team_p_h['장타율_h'] = team_p_h.apply(jangta,axis=1)

# 타율
team_p_h['타율_h'] = team_p_h.apply(ta,axis=1)

# 사구/타수
team_p_h['사구/타수_h'] = team_p_h.apply(sagu,axis=1)

# 삼진/타수
team_p_h['삼진/타수_h'] = team_p_h.apply(samjin,axis=1)

# %% [markdown]
# **5.2.3 사용하지 않는 피처 제거후 컬럼 정렬**

# %%
# 새로운 피처 생성하며 사용한 피처 제거
team_p_h = team_p_h.drop(['더블헤더코드','초말', '2루타_h', '3루타_h', 
                          '홈런_h', '4구_h',  '사구_h', '삼진_h', '타자_p',
                         '타수_p', '안타_p', '2루타_p', '3루타_p', '홈런_p', '4구_p',
                         '고4_p', '삼진_p'],axis=1)

team_p_h = team_p_h.drop(['게임키', '일자', '결과_p'], axis=1)

# 컬럼 재정렬
team_p_h = team_p_h[[ '년도', '상/하', '팀코드', '상대팀코드', '타자_h', '타점_h', '득점_h', '도루_h', '도루실패_h', '희타_h',
       '희비_h', '고4_h', '병살타_h', '실책_h', '잔루_h', '득점권타율_h', '득점권타수_h',
       '득점권안타_h', '완투_p', '홀드_p', '투구수_p', '도루_p', '도루실패_p', '희타_p', '희비_p',
       '사구_p', '병살타_p', '폭투_p', '보크_p', '실책_p', '실점_p', '득점권WHIP_p',
       '2점차이하WHIP_p', '345번타자WHIP_p', '실점/이닝_p', '삼진/이닝_p', '볼넷/이닝_p', '삼진/볼넷_p', '피홈런/이닝_p', '타자/이닝_p',
       'WHIP_p', '출루율_h', '장타율_h', '타율_h', '사구/타수_h', '삼진/타수_h', 
        '평균자책점_p', '피안타율_p', '타수_h', '안타_h', '자책점_p', '이닝*3_p']]

# %%
team_p_h.head(3)
# Out:
#      년도 상/하 팀코드 상대팀코드  타자_h  타점_h  득점_h  도루_h  도루실패_h  희타_h  희비_h  고4_h  \
# 0  2016   상  LG    HH    47     4     5     2       1     1     0     0
# 1  2016   상  HH    LG    52     4     4     0       0     3     0     0
# 2  2016   상  NC    HT    36     5     5     0       0     1     0     0
#
#    병살타_h  실책_h  잔루_h   득점권타율_h  득점권타수_h  득점권안타_h  완투_p  홀드_p  투구수_p  도루_p  \
# 0      0     0     8  0.333333       12        4     0     0    184     0
# 1      1     2    12  0.200000       15        3     0     0    196     2
# 2      1     1     7  0.142857        7        1     0     0    143     0
#
#    도루실패_p  희타_p  희비_p  사구_p  병살타_p  폭투_p  보크_p  실책_p  실점_p  득점권WHIP_p  \
# 0       0     3     0     0      1     0     0     0     4   0.642857
# 1       1     1     0     0      0     1     0     0     5   1.500000
# 2       0     0     0     1      1     2     0     0     4   1.333333
#
#    2점차이하WHIP_p  345번타자WHIP_p   실점/이닝_p    삼진/이닝_p   볼넷/이닝_p   삼진/볼넷_p  \
# ...

# %% [markdown]
# ---
#
# ## 5.4  종속변수 생성

# %% [markdown]
# **데이터셋의 ‘결과’변수를 이용하여 승률 계산**
#
# * 2016년 상반기 변수의 반응변수 ￫ 2016년 하반기 경기 승률
#
# * 2016년 하반기 변수의 반응변수 ￫ 2017년 상반기 경기 승률
#
# * 2017년 상반기 변수의 반응변수 ￫ 2017년 하반기 경기 승률
#
#                                           ⋮
#
# * 2019년 상반기 변수의 반응변수 ￫ 2019년 하반기 경기 승률
#
# * 2019년 하반기 변수의 반응변수 ￫ 2020년 상반기 경기 승률
#
# * 2020년 상반기 변수의 반응변수 ￫ 		NULL

# %% [markdown]
# **5.4.1 승률**

# %%
def target(x):
        t = pd.DataFrame(x.groupby('결과_p').count()['게임키'])
        return  t['게임키'][-1 ] / ( t['게임키'][-1] + t['게임키'][-2] )
    
teams = ['HT','OB','LT','NC','SK','LG','WO','HH','SS','KT']
years = [2016,2017,2018,2019]
seasons = ['상','하']

result = []

for team in teams:
    for year in years:
        for season in seasons:
            if season == '상':
                tys = DATA[(DATA['팀코드']==team)&(DATA['년도']==year)&(DATA['상/하']=='하')]
            else:
                tys = DATA[(DATA['팀코드']==team)&(DATA['년도']==year+1)&(DATA['상/하']=='상')]
            result.append(target(tys))

result = pd.DataFrame(result)
result.rename(columns={0:'result'},inplace=True)

teams = ['HT','OB','LT','NC','SK','LG','WO','HH','SS','KT']
years = [2016,2017,2018,2019]
seasons = ['상','하']

obs = []

for team in teams:
    for year in years:
        for season in seasons:
            obs.append(team+str(year)+season)
            
obs = pd.DataFrame(obs)
obs.rename(columns={0:'obs'},inplace=True)

TARGET = pd.concat([obs,result],axis=1)

# %% [markdown]
# **5.4.2 타율 & 방어율**

# %%
# 종속변수 제외 피처들은 mean 처리
team_p_h_mean = team_p_h.drop(['타수_h', '안타_h', '자책점_p', '이닝*3_p'], axis=1)
team_p_h_mean = team_p_h_mean.groupby(['년도', '상/하', '팀코드', '상대팀코드'], as_index=False).mean()
team_p_h_mean.head(3)
# Out:
#      년도 상/하 팀코드 상대팀코드       타자_h      타점_h      득점_h      도루_h    도루실패_h  \
# 0  2016   상  HH    HT  38.125000  3.250000  3.375000  0.875000  0.375000
# 1  2016   상  HH    KT  42.000000  6.125000  6.250000  0.625000  0.125000
# 2  2016   상  HH    LG  41.555556  4.222222  4.333333  0.111111  0.111111
#
#     희타_h      희비_h      고4_h     병살타_h      실책_h      잔루_h   득점권타율_h  \
# 0  0.625  0.250000  0.125000  1.000000  1.000000  8.250000  0.189435
# 1  0.375  0.125000  0.125000  1.000000  0.625000  8.000000  0.251689
# 2  1.000  0.222222  0.666667  1.333333  0.888889  8.555556  0.242641
#
#     득점권타수_h   득점권안타_h  완투_p      홀드_p    투구수_p      도루_p    도루실패_p   희타_p  \
# 0  8.250000  1.875000   0.0  0.500000  152.375  0.500000  0.750000  0.250
# 1  9.875000  2.500000   0.0  0.000000  166.375  1.125000  0.500000  0.625
# 2  9.888889  2.444444   0.0  0.333333  173.000  0.888889  0.666667  1.000
#
#        희비_p      사구_p     병살타_p      폭투_p  보크_p      실책_p      실점_p  \
# ...

# %%
# 종속변수 관련 피처들은 sum 처리
team_p_h_sum = team_p_h[['년도', '상/하', '팀코드', '상대팀코드', '타수_h', '안타_h', '자책점_p', '이닝*3_p']]
team_p_h_sum = team_p_h_sum.groupby(['년도', '상/하', '팀코드', '상대팀코드'], as_index=False).sum()
team_p_h_sum.head(3)
# Out:
#      년도 상/하 팀코드 상대팀코드  타수_h  안타_h  자책점_p  이닝*3_p
# 0  2016   상  HH    HT   265    69     36     213
# 1  2016   상  HH    KT   296    83     68     210
# 2  2016   상  HH    LG   325    88     54     253

# %%
# 종속 변수 생성하는 함수

new_team_p_h = team_p_h_mean.merge(team_p_h_sum)

def make_y(df, VS, T_VS):
    df = df[(df['팀코드'] == VS) & (df['상대팀코드'] == T_VS)]
    df = df.sort_values(by=['팀코드', '상대팀코드', '년도', '상/하']).head(10).reset_index()
    y = df[['타수_h', '안타_h', '자책점_p', '이닝*3_p']].drop([df.index[0]])
    y.columns = ['타수_h_next', '안타_h_next', '자책점_p_next', '이닝*3_p_next']
    y = y.append({'타수_h_next':0, '안타_h_next':0, '자책점_p_next':0, '이닝*3_p_next':0}, ignore_index=True)
    df = pd.concat([df, y], axis=1)
    df = df.drop(['index'], axis=1)
    return df

result_AVG_ERA = None
team = ['HH', 'HT', 'KT', 'LG', 'LT', 'NC', 'OB', 'SK', 'SS', 'WO']

for i in team:
    for j in team:
        if i != j:
            result_by_team = make_y(new_team_p_h, i, j)
            result_AVG_ERA = pd.concat([result_AVG_ERA, result_by_team], axis=0)

final_AVG_ERA = result_AVG_ERA.drop(result_AVG_ERA.loc[(result_AVG_ERA['년도'] == 2020) & (result_AVG_ERA['상/하'] == '상')].index)

# %% [markdown]
# # 6. 최종 데이터셋(Final data set)

# %% [markdown]
# ## 6.1 승률

# %%
def obs(x):
    return (x['팀코드']+str(x['년도'])+x['상/하'])

DATA['obs']=DATA.apply(obs,axis=1)

FINAL = pd.merge(DATA,TARGET,left_on=['obs'],right_on=['obs'],how='left')

# %%
FINAL.head(3)
# Out:
#              게임키    년도        일자 팀코드 상대팀코드 결과_p    피안타율_p   평균자책점_p   실점/이닝_p  \
# 0  20160401HHLG0  2016  20160401  LG    HH    W  0.282609  3.000000  3.000000
# 1  20160401HHLG0  2016  20160401  HH    LG    L  0.214286  3.176471  3.970588
# 2  20160401HTNC0  2016  20160401  NC    HT    W  0.235294  4.000000  4.000000
#
#     볼넷/이닝_p   삼진/볼넷_p  피홈런/이닝_p    타자/이닝_p     WHIP_p   득점권타율_h     출루율_h  \
# 0  2.250000  3.333333  0.000000  39.000000  13.500000  0.333333  0.282609
# 1  3.176471  2.750000  0.794118  37.323529  12.705882  0.200000  0.326531
# 2  3.000000  3.333333  1.000000  38.000000  15.000000  0.142857  0.400000
#
#       장타율_h      타율_h   사구/타수_h   삼진/타수_h         나이            연봉 상/하  \
# 0  0.333333  0.214286  0.095238  0.261905  27.939394  14245.833333   상
# 1  0.326087  0.282609  0.065217  0.217391  29.229730  20037.329730   상
# 2  0.566667  0.300000  0.166667  0.300000  25.940299  13309.029851   상
#
#          OBS  전년도승률  전년도상대승률      obs    result
# ...

# %% [markdown]
# ## 6.2 타율 & 방어율

# %%
final_AVG_ERA.head(3)
# Out:
#      년도 상/하 팀코드 상대팀코드    타자_h  타점_h   득점_h   도루_h  도루실패_h   희타_h  희비_h   고4_h  \
# 0  2016   상  HH    HT  38.125  3.25  3.375  0.875   0.375  0.625  0.25  0.125
# 1  2016   하  HH    HT  42.375  4.25  4.750  0.375   0.500  0.500  0.00  0.125
# 2  2017   상  HH    HT  38.125  3.25  3.375  0.250   0.250  0.000  0.50  0.000
#
#    병살타_h   실책_h    잔루_h   득점권타율_h  득점권타수_h  득점권안타_h  완투_p   홀드_p    투구수_p  \
# 0  1.000  1.000   8.250  0.189435    8.250    1.875   0.0  0.500  152.375
# 1  0.875  0.625  10.375  0.262665   12.000    3.375   0.0  0.375  157.750
# 2  0.875  0.250   7.750  0.263969    7.875    2.000   0.0  0.000  146.000
#
#     도루_p  도루실패_p   희타_p   희비_p  사구_p  병살타_p   폭투_p  보크_p   실책_p   실점_p  \
# 0  0.500   0.750  0.250  0.000  0.75  0.375  0.250   0.0  0.125  5.250
# 1  1.125   0.625  0.375  0.625  0.75  0.375  0.500   0.0  0.125  4.750
# 2  0.625   0.375  0.750  0.500  0.50  0.750  0.375   0.0  0.250  6.625
#
# ...

# %% [markdown]
# **범주형 변수 처리**
# - LabelEncoder를 통해서 숫자로 변환한다

# %%
#팀코드 
FINAL['팀코드'] = LabelEncoder().fit_transform(FINAL['팀코드'])
team = LabelEncoder()
team.fit(final_AVG_ERA['팀코드'])
final_AVG_ERA['팀코드'] = team.transform(final_AVG_ERA['팀코드'])

#상대팀코드
FINAL['상대팀코드'] = LabelEncoder().fit_transform(FINAL['상대팀코드'])
team_vs = LabelEncoder()
team_vs.fit(final_AVG_ERA['상대팀코드'])
final_AVG_ERA['상대팀코드'] = team_vs.transform(final_AVG_ERA['상대팀코드'])

# 상/하
season = LabelEncoder()
season.fit(final_AVG_ERA['상/하'])
final_AVG_ERA['상/하'] = season.transform(final_AVG_ERA['상/하'])

# %% [markdown]
# # 7. 모델링 (Modeling)

# %% [markdown]
# ## 7.1 승률

# %%
TO = FINAL[FINAL['년도']!=2020]

# %%
col = ['년도','팀코드','상대팀코드','피안타율_p','평균자책점_p','실점/이닝_p','볼넷/이닝_p','삼진/볼넷_p','피홈런/이닝_p','타자/이닝_p','WHIP_p','득점권타율_h','출루율_h','장타율_h','타율_h','사구/타수_h','삼진/타수_h','전년도승률','전년도상대승률','나이','연봉']

# %%
X_train, X_test, y_train, y_test = train_test_split(TO[col], 
                                                    TO.result, 
                                                    test_size=0.3)

# %%
# 랜덤포레스트 객체 생성
model = RandomForestRegressor(n_estimators=300,random_state=42)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=300, random_state=42)

# %%
imp_data = pd.DataFrame(model.feature_importances_, index = X_train.columns,columns=['중요도'])
imp_data
# Out:
#                중요도
# 년도        0.066297
# 팀코드       0.049249
# 상대팀코드     0.013176
# 피안타율_p    0.021106
# 평균자책점_p   0.012665
# 실점/이닝_p   0.012591
# 볼넷/이닝_p   0.013603
# 삼진/볼넷_p   0.021193
# 피홈런/이닝_p  0.010974
# 타자/이닝_p   0.019147
# WHIP_p    0.016423
# 득점권타율_h   0.021376
# 출루율_h     0.020133
# 장타율_h     0.024554
# 타율_h      0.021241
# 사구/타수_h   0.025903
# 삼진/타수_h   0.028485
# 전년도승률     0.348362
# 전년도상대승률   0.012088
# 나이        0.190476
# 연봉        0.050958

# %%
score = round(model.score(X_test,y_test) *100,3)
score
# Out:
# 64.877

# %%
y_pred = model.predict(TO[col])

# %%
r2_score(TO.result,y_pred)
# Out:
# 0.8611334907031993

# %% [markdown]
# ## 7.2 타율
# 타율 자체를 예측하는 대신 타율을 계산할 때 사용되는 타수와 안타수를 예측함

# %%
X = final_AVG_ERA.drop(['타수_h_next', '안타_h_next', '자책점_p_next', '이닝*3_p_next'], axis=1)
y1 = final_AVG_ERA['타수_h_next']
y2 = final_AVG_ERA['안타_h_next']

# %% [markdown]
# ### 7.2.1 타수(AB)

# %%
X_train_AB, X_test_AB, y_train_AB, y_test_AB = train_test_split(X, y1,
                                                    test_size=0.2,
                                                    random_state=42,
                                                    shuffle=False
                                                   )

# %%
model_rf_AB = RandomForestRegressor()
model_rf_AB.fit(X_train_AB,y_train_AB)
print("훈련 세트 정확도: {:.3f}".format(model_rf_AB.score(X_train_AB, y_train_AB)))
print("테스트 세트 정확도: {:.3f}".format(model_rf_AB.score(X_test_AB, y_test_AB)))
# Out:
# 훈련 세트 정확도: 0.956
# 테스트 세트 정확도: 0.749

# %% [markdown]
# ### 7.2.2 안타수(H)

# %%
X_train_H, X_test_H, y_train_H, y_test_H = train_test_split(X, y2,
                                                    test_size=0.2,
                                                    random_state=42,
                                                    shuffle=False
                                                   )

# %%
model_rf_H = RandomForestRegressor()
model_rf_H.fit(X_train_H,y_train_H)
print("훈련 세트 정확도: {:.3f}".format(model_rf_H.score(X_train_H, y_train_H)))
print("테스트 세트 정확도: {:.3f}".format(model_rf_H.score(X_test_H, y_test_H)))
# Out:
# 훈련 세트 정확도: 0.936
# 테스트 세트 정확도: 0.571

# %% [markdown]
# ## 7.3 방어율
# 방어율 자체를 예측하는 대신 방어율을 계산할 때 사용되는 자책점과 이닝수*3을 예측함

# %%
y3 = final_AVG_ERA['자책점_p_next']
y4 = final_AVG_ERA['이닝*3_p_next']

# %% [markdown]
# ### 7.3.1 자책점(ER)

# %%
X_train_ER, X_test_ER, y_train_ER, y_test_ER = train_test_split(X, y3,
                                                    test_size=0.2,
                                                    random_state=42,
                                                    shuffle=False
                                                   )

# %%
model_rf_ER = RandomForestRegressor()
model_rf_ER.fit(X_train_ER,y_train_ER)
print("훈련 세트 정확도: {:.3f}".format(model_rf_ER.score(X_train_ER, y_train_ER)))
print("테스트 세트 정확도: {:.3f}".format(model_rf_ER.score(X_test_ER, y_test_ER)))
# Out:
# 훈련 세트 정확도: 0.912
# 테스트 세트 정확도: 0.402

# %% [markdown]
# ### 7.3.2 이닝*3(I)

# %%
X_train_I, X_test_I, y_train_I, y_test_I = train_test_split(X, y4,
                                                    test_size=0.2,
                                                    random_state=42,
                                                    shuffle=False
                                                   )

# %%
model_rf_I = RandomForestRegressor()
model_rf_I.fit(X_train_I,y_train_I)
print("훈련 세트 정확도: {:.3f}".format(model_rf_I.score(X_train_I, y_train_I)))
print("테스트 세트 정확도: {:.3f}".format(model_rf_I.score(X_test_I, y_test_I)))
# Out:
# 훈련 세트 정확도: 0.956
# 테스트 세트 정확도: 0.765

# %% [markdown]
# # 8. Testing

# %% [markdown]
# ## 8.1 승률

# %%
## 예측해야하는 2020년 7월 19일 이후의 승률을 구하기위해,
## 2020년 5월 5일부터 시작해 7월 19일까지의 경기를 상반기 경기로 지정해두고 모델에 넣기 위해 PRED 데이터 프레임 생성

PRED = FINAL[FINAL['년도']==2020]
PRED = PRED[col]

Y_PRED = model.predict(PRED)
Y_PRED = pd.DataFrame(Y_PRED)
Y_PRED.rename(columns={0 : '예측승률'},inplace=True)

REST_GAMES = pd.concat([PRED.reset_index(drop=True),Y_PRED],axis =1)

REST_GAMES.head()
# Out:
#      년도  팀코드  상대팀코드    피안타율_p  평균자책점_p  실점/이닝_p  볼넷/이닝_p  삼진/볼넷_p  피홈런/이닝_p  \
# 0  2020    7      0  0.258065      3.0      3.0      2.0     2.50       0.0
# 1  2020    0      7  0.068966      0.0      0.0      1.0     2.00       0.0
# 2  2020    2      4  0.218750      7.0      7.0      4.0     2.25       2.0
# 3  2020    4      2  0.166667      2.0      2.0      5.0     1.60       1.0
# 4  2020    8      5  0.212121      4.0      4.0      2.0     4.50       3.0
#
#    타자/이닝_p  WHIP_p   득점권타율_h     출루율_h     장타율_h      타율_h   사구/타수_h  \
# 0     35.0    13.0  0.000000  0.100000  0.068966  0.068966  0.034483
# 1     30.0     3.0  0.250000  0.303030  0.354839  0.258065  0.064516
# 2     37.0    14.0  0.000000  0.285714  0.300000  0.166667  0.166667
# 3     35.0    12.0  0.666667  0.305556  0.437500  0.218750  0.125000
# 4     35.0    14.0  0.000000  0.250000  0.100000  0.100000  0.200000
#
#     삼진/타수_h  전년도승률   전년도상대승률         나이            연봉      예측승률
# ...

# %%
TEAMS = pd.pivot_table(REST_GAMES ,index='팀코드')
TEAMS
# Out:
#         WHIP_p         나이    년도   득점권타율_h   볼넷/이닝_p   사구/타수_h    삼진/볼넷_p  \
# 팀코드
# 0    18.379774  27.614286  2020  0.216755  4.148131  0.107495   8.217429
# 1    15.097637  26.920635  2020  0.254841  3.125616  0.122654   9.542550
# 2    16.432909  26.796875  2020  0.250629  3.659325  0.105071   6.824219
# 3    15.980163  28.114754  2020  0.303916  3.181909  0.108383   6.210714
# 4    15.640030  27.406250  2020  0.263416  3.235899  0.110365  10.694121
# 5    14.610402  26.724138  2020  0.307134  3.588849  0.114018   6.199005
# 6    17.041070  26.619048  2020  0.304777  3.394340  0.116694  10.061062
# 7    16.639593  27.645161  2020  0.209424  4.328209  0.112339   3.737320
# 8    15.932308  26.983871  2020  0.271577  3.802692  0.112514   6.976252
# 9    15.440844  26.333333  2020  0.268387  2.852815  0.141228  12.062229
#
#       삼진/타수_h     상대팀코드   실점/이닝_p            연봉      예측승률     장타율_h   전년도상대승률  \
# 팀코드
# ...

# %%
team = ['HH','HT','KT','LG','LT','NC','OB','SK','SS','WO']
team = pd.DataFrame(team)
team.rename(columns = {0:'팀코드'},inplace=True)

RESULT = pd.concat([team.reset_index(drop=True), pd.DataFrame(TEAMS['예측승률'])] , axis =1 )
RESULT
# Out:
#   팀코드      예측승률
# 0  HH  0.443353
# 1  HT  0.576682
# 2  KT  0.466713
# 3  LG  0.422375
# 4  LT  0.438894
# 5  NC  0.463004
# 6  OB  0.471231
# 7  SK  0.436616
# 8  SS  0.561378
# 9  WO  0.454880

# %%
np.mean(RESULT['예측승률']) #10개 팀의 승률에 대한 평균
# Out:
# 0.47351262092558927

# %% [markdown]
# ## 8.2 타율

# %%
# 팀코드 
result_AVG_ERA['팀코드'] = LabelEncoder().fit_transform(result_AVG_ERA['팀코드'])

# 상대팀코드
result_AVG_ERA['상대팀코드'] = LabelEncoder().fit_transform(result_AVG_ERA['상대팀코드'])

# 상/하
result_AVG_ERA['상/하'] = LabelEncoder().fit_transform(result_AVG_ERA['상/하'])

# %%
col = ['년도', '상/하', '팀코드', '상대팀코드', '타자_h', '타점_h', '득점_h', '도루_h', '도루실패_h',
       '희타_h', '희비_h', '고4_h', '병살타_h', '실책_h', '잔루_h', '득점권타율_h', '득점권타수_h',
       '득점권안타_h', '완투_p', '홀드_p', '투구수_p', '도루_p', '도루실패_p', '희타_p', '희비_p',
       '사구_p', '병살타_p', '폭투_p', '보크_p', '실책_p', '실점_p', '득점권WHIP_p',
       '2점차이하WHIP_p', '345번타자WHIP_p', '실점/이닝_p', '삼진/이닝_p', '볼넷/이닝_p',
       '삼진/볼넷_p', '피홈런/이닝_p', '타자/이닝_p', 'WHIP_p', '출루율_h', '장타율_h', '타율_h',
       '사구/타수_h', '삼진/타수_h', '평균자책점_p', '피안타율_p', '타수_h', '안타_h', '자책점_p',
       '이닝*3_p']

# %%
pred = result_AVG_ERA[(result_AVG_ERA['년도']==2020)]
pred = pred[col]

# %% [markdown]
# **8.2.1 타수(AB)**

# %%
y_pred_AB = model_rf_AB.predict(pred)
y_pred_AB = pd.DataFrame(y_pred_AB)
y_pred_AB.rename(columns={0 : '예측타수'},inplace=True)

# %% [markdown]
# **8.2.2 안타수(H)**

# %%
y_pred_H = model_rf_H.predict(pred)
y_pred_H = pd.DataFrame(y_pred_H)
y_pred_H.rename(columns={0 : '예측안타수'},inplace=True)

# %% [markdown]
# **8.2.3 타율 = 안타수 / 타수**

# %%
y_pred_H_AB = pd.concat([y_pred_H, y_pred_AB], axis=1)
y_pred_H_AB
# Out:
#     예측안타수    예측타수
# 0   65.48  253.19
# 1   60.30  228.67
# 2   59.66  208.51
# 3   61.43  239.47
# 4   56.41  206.54
# ..    ...     ...
# 85  67.52  258.85
# 86  57.73  222.16
# 87  59.26  186.66
# 88  62.45  232.30
# 89  60.64  226.81
#
# [90 rows x 2 columns]

# %%
REST_GAMES_AVG = pd.concat([pred.reset_index(drop=True),y_pred_H_AB],axis =1)
REST_GAMES_AVG['예측타율'] = REST_GAMES_AVG['예측안타수'] / REST_GAMES_AVG['예측타수']
TEAMS_AVG = pd.pivot_table(REST_GAMES_AVG ,index='팀코드')

# %%
RESULT_AVG = pd.concat([team.reset_index(drop=True), pd.DataFrame(TEAMS_AVG['예측타율'])] , axis =1 )
RESULT_AVG
# Out:
#   팀코드      예측타율
# 0  HH  0.265665
# 1  HT  0.272740
# 2  KT  0.274255
# 3  LG  0.280529
# 4  LT  0.270439
# 5  NC  0.271561
# 6  OB  0.282282
# 7  SK  0.268282
# 8  SS  0.271770
# 9  WO  0.275269

# %% [markdown]
# ## 8.3 방어율

# %% [markdown]
# **8.3.1 자책점(ER)**

# %%
y_pred_ER = model_rf_ER.predict(pred)
y_pred_ER = pd.DataFrame(y_pred_ER)
y_pred_ER.rename(columns={0 : '예측자책점'},inplace=True)

# %% [markdown]
# **8.3.2 이닝*3(I)**

# %%
y_pred_I = model_rf_I.predict(pred)
y_pred_I = pd.DataFrame(y_pred_I)
y_pred_I.rename(columns={0 : '예측이닝*3'},inplace=True)

# %% [markdown]
# **8.3.3 방어율 = 자책점 * 27 / (이닝*3 / 3 ) * 9**

# %%
y_pred_ER_I = pd.concat([y_pred_ER, y_pred_I], axis=1)
y_pred_ER_I
# Out:
#     예측자책점  예측이닝*3
# 0   30.63  181.81
# 1   30.05  176.13
# 2   30.41  169.15
# 3   29.39  184.24
# 4   33.36  167.88
# ..    ...     ...
# 85  35.75  195.73
# 86  26.51  172.95
# 87  32.26  142.14
# 88  27.66  183.99
# 89  32.67  187.09
#
# [90 rows x 2 columns]

# %%
REST_GAMES_ERA = pd.concat([pred.reset_index(drop=True),y_pred_ER_I],axis =1)
REST_GAMES_ERA['예측방어율'] = REST_GAMES_ERA['예측자책점'] / (REST_GAMES_ERA['예측이닝*3']/3)*9
TEAMS_ERA = pd.pivot_table(REST_GAMES_ERA ,index='팀코드')

# %%
RESULT_ERA = pd.concat([team.reset_index(drop=True), pd.DataFrame(TEAMS_ERA['예측방어율'])] , axis =1 )
RESULT_ERA
# Out:
#   팀코드     예측방어율
# 0  HH  4.736421
# 1  HT  4.583385
# 2  KT  5.175031
# 3  LG  4.870695
# 4  LT  4.745764
# 5  NC  4.363605
# 6  OB  4.663989
# 7  SK  4.959545
# 8  SS  4.777652
# 9  WO  4.592439

# %% [markdown]
# # 9. Result
# 2020년도 하반기의 팀별 승률, 타율, 방어율 예측

# %% [markdown]
# ## 9.1 팀별 승률 예측

# %%
RESULT
# Out:
#   팀코드      예측승률
# 0  HH  0.443353
# 1  HT  0.576682
# 2  KT  0.466713
# 3  LG  0.422375
# 4  LT  0.438894
# 5  NC  0.463004
# 6  OB  0.471231
# 7  SK  0.436616
# 8  SS  0.561378
# 9  WO  0.454880

# %%
sns.barplot(x="팀코드", y="예측승률", data=RESULT)

# %% [markdown]
# ## 9.2 팀별 타율 예측

# %%
RESULT_AVG
# Out:
#   팀코드      예측타율
# 0  HH  0.265665
# 1  HT  0.272740
# 2  KT  0.274255
# 3  LG  0.280529
# 4  LT  0.270439
# 5  NC  0.271561
# 6  OB  0.282282
# 7  SK  0.268282
# 8  SS  0.271770
# 9  WO  0.275269

# %%
sns.barplot(x="팀코드", y="예측타율", data=RESULT_AVG)

# %% [markdown]
# ## 9.3 팀별 방어율 예측

# %%
RESULT_ERA
# Out:
#   팀코드     예측방어율
# 0  HH  4.736421
# 1  HT  4.583385
# 2  KT  5.175031
# 3  LG  4.870695
# 4  LT  4.745764
# 5  NC  4.363605
# 6  OB  4.663989
# 7  SK  4.959545
# 8  SS  4.777652
# 9  WO  4.592439

# %%
sns.barplot(x="팀코드", y="예측방어율", data=RESULT_ERA)

# %% [markdown]
# # 10. Reference

# %% [markdown]
# - https://blog.ncsoft.com/rd/data-science/
# - https://www.koreabaseball.com/Schedule/GameCenter/Main.aspx
# - https://sites.google.com/site/eveningglow17/record/yagu-yong-eo-jeongli : 야구 관련 용어
# - https://corporatefinanceinstitute.com/resources/knowledge/other/random-forest/
